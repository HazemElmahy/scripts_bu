# %%
import math

radius = 100
x = 0
y = 0

for angle in range(361):
    radians = math.radians(angle)
    x = radius * math.cos(radians)
    y = radius * math.sin(radians)
    print(int(x),int(y))
    # Draw the point (x, y) on the circle border
    # (You would need to use the appropriate graphics library or framework for drawing)
# Out:
# 100 0
# 99 1
# 99 3
# 99 5
# 99 6
# 99 8
# 99 10
# 99 12
# 99 13
# 98 15
# 98 17
# 98 19
# 97 20
# 97 22
# 97 24
# 96 25
# 96 27
# 95 29
# 95 30
# 94 32
# 93 34
# 93 35
# 92 37
# 92 39
# 91 40
# 90 42
# 89 43
# 89 45
# 88 46
# 87 48
# 86 49
# 85 51
# 84 52
# 83 54
# 82 55
# 81 57
# 80 58
# 79 60
# 78 61
# 77 62
# 76 64
# 75 65
# 74 66
# 73 68
# 71 69
# 70 70
# 69 71
# 68 73
# 66 74
# 65 75
# 64 76
# 62 77
# 61 78
# 60 79
# 58 80
# 57 81
# 55 82
# 54 83
# 52 84
# 51 85
# 50 86
# 48 87
# 46 88
# 45 89
# 43 89
# 42 90
# 40 91
# 39 92
# 37 92
# 35 93
# 34 93
# 32 94
# 30 95
# 29 95
# 27 96
# 25 96
# 24 97
# 22 97
# 20 97
# 19 98
# 17 98
# 15 98
# 13 99
# 12 99
# 10 99
# 8 99
# 6 99
# 5 99
# 3 99
# 1 99
# 0 100
# -1 99
# -3 99
# -5 99
# -6 99
# -8 99
# -10 99
# -12 99
# -13 99
# -15 98
# -17 98
# -19 98
# -20 97
# -22 97
# -24 97
# -25 96
# -27 96
# -29 95
# -30 95
# -32 94
# -34 93
# -35 93
# -37 92
# -39 92
# -40 91
# -42 90
# -43 89
# -45 89
# -46 88
# -48 87
# -49 86
# -51 85
# ...
